# %% [markdown]
# # Image to sketch

# %% [markdown]
# # LGMVIP Task-4|| Data Science

# %% [markdown]
# #### We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import cv2

# %%
im = cv2.imread('ankit.jpg')
im_resized = cv2.resize(im, (340, 340), interpolation=cv2.INTER_LINEAR)

# %%
plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Convert Coloured image to Grey_Scale Image

# %%
image_grey = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im_resized = cv2.resize(image_grey, (340, 340), interpolation=cv2.INTER_LINEAR)
plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Inverting the grayscale image

# %%
image_invert = cv2.bitwise_not(image_gray)
im_resized = cv2.resize(image_invert, (340, 340), interpolation=cv2.INTER_LINEAR)
plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### Blurring the image using gaussian function

# %%
blur = cv2.GaussianBlur(image_invert, (21, 21), 0)

# %% [markdown]
# ### inverting the blurred image

# %%
blur_invert = 255-blur

# %% [markdown]
# ## Final Sketch

# %%
final_sketch = cv2.divide(image_gray, blur_invert, scale=256.0)
im_resized = cv2.resize(final_sketch, (340, 340), interpolation=cv2.INTER_LINEAR)
plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()
